# %%
import pandas as pd
import numpy as np

# %%
DATA_PATH = "../data/raw/telco_customer_churn.csv"

# %%
df = pd.read_csv(DATA_PATH)

print(f"Dataset shape: {df.shape}")
# Out:
# Dataset shape: (7043, 33)

# %%
constant_columns = [
    column
    for column in df.columns
    if df[column].nunique(dropna=False) <= 1
]

# %%
print("Constant columns:")
print(constant_columns)
# Out:
# Constant columns:
# ['Count', 'Country', 'State']

# %%
unique_counts = (
    df.nunique().sort_values().to_frame("unique_values")
)
unique_counts
# Out:
#                    unique_values
# Count                          1
# Country                        1
# State                          1
# Phone Service                  2
# Dependents                     2
# Partner                        2
# Senior Citizen                 2
# Gender                         2
# Churn Value                    2
# Paperless Billing              2
# Churn Label                    2
# Multiple Lines                 3
# Internet Service               3
# Online Backup                  3
# Online Security                3
# Tech Support                   3
# Contract                       3
# Streaming Movies               3
# Streaming TV                   3
# Device Protection              3
# Payment Method                 4
# Churn Reason                  20
# Tenure Months                 73
# Churn Score                   85
# City                        1129
# Monthly Charges             1585
# Longitude                   1651
# ...

# %%
TARGET = "Churn Label"
X = df.drop(columns=[TARGET])
y = df[TARGET]

# %%
print("Features:", X.shape)
print("Target:", y.shape)
# Out:
# Features: (7043, 32)
# Target: (7043,)

# %%
y.value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
y.value_counts(normalize=True) * 100
# Out:
# Churn Label
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
# first feature groups
numerical_features = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_features = df.select_dtypes(include=["object"]).columns.tolist()
# Out:
# C:\Users\Tanish_Gupta\AppData\Local\Temp\ipykernel_13508\1351054156.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_features = df.select_dtypes(include=["object"]).columns.tolist()

# %%
print("Numerical features:")
print(numerical_features)

print("\nCategorical features:")
print(categorical_features)
# Out:
# Numerical features:
# ['Count', 'Zip Code', 'Latitude', 'Longitude', 'Tenure Months', 'Monthly Charges', 'Churn Value', 'Churn Score', 'CLTV']
#
# Categorical features:
# ['CustomerID', 'Country', 'State', 'City', 'Lat Long', 'Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method', 'Total Charges', 'Churn Label', 'Churn Reason']

# %%
df["Total Charges"].unique()[:20]
# Out:
# <StringArray>
# [ '108.15',  '151.65',   '820.5', '3046.05',  '5036.3',  '528.35',   '39.65',
#    '20.15', '4749.15',    '30.2',  '1093.1',   '316.9', '3549.25',  '1105.4',
#   '144.15',  '1426.4',   '633.3', '1752.55',  '857.25',   '79.35']
# Length: 20, dtype: str

# %%
df["Total Charges"].isna().sum()
# Out:
# np.int64(0)

# %%
blank_total_charges = (df["Total Charges"].astype(str).str.strip() == "")
print("Blank Total Charges:", blank_total_charges.sum())
# Out:
# Blank Total Charges: 11

# %%
columns_to_investigate = [
    "Count",
    "Country",
    "State",
    "CustomerID",
    "Churn Value",
    "Churn Score",
    "Churn Reason"
]
for column in columns_to_investigate:
    print(f"\n--- {column} ---")
    print("Unique values:", df[column].nunique())
    print(df[column].dropna().unique()[:10])
# Out:
# --- Count ---
# Unique values: 1
# [1]
#
# --- Country ---
# Unique values: 1
# <StringArray>
# ['United States']
# Length: 1, dtype: str
#
# --- State ---
# Unique values: 1
# <StringArray>
# ['California']
# Length: 1, dtype: str
#
# --- CustomerID ---
# Unique values: 7043
# <StringArray>
# ['3668-QPYBK', '9237-HQITU', '9305-CDSKC', '7892-POOKP', '0280-XJGEX',
#  '4190-MFLUW', '8779-QRDMV', '1066-JKSGK', '6467-CHFZW', '8665-UTDHZ']
# Length: 10, dtype: str
#
# --- Churn Value ---
# Unique values: 2
# [1 0]
#
# --- Churn Score ---
# Unique values: 85
# [ 86  67  84  89  78 100  92  77  97  74]
#
# --- Churn Reason ---
# Unique values: 20
# <StringArray>
# [             'Competitor made better offer',
#                                      'Moved',
#              'Competitor had better devices',
#  'Competitor offered higher download speeds',
#               'Competitor offered more data',
#                             'Price too high',
# ...
